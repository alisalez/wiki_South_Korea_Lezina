# %%
# !wget https://raw.githubusercontent.com/alisalez/wiki_South_Korea_Lezina/refs/heads/main/wiki_south_korea.txt
# Out:
# --2024-11-20 07:21:09--  https://raw.githubusercontent.com/alisalez/wiki_South_Korea_Lezina/refs/heads/main/wiki_south_korea.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88818 (87K) [text/plain]
# Saving to: ‘wiki_south_korea.txt.1’
#
# wiki_south_korea.tx 100%[===================>]  86.74K  --.-KB/s    in 0.03s
#
# 2024-11-20 07:21:09 (2.82 MB/s) - ‘wiki_south_korea.txt.1’ saved [88818/88818]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'wiki_south_korea.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# 'lation of 51.96 million, of which half live in the seoul capital area, the ninth most populous metropolitan area in the world. other major cities include busan, daegu, and incheon.\n\nthe korean peninsula was inhabited as early as the lower paleolithic period. its first kingdom was noted in chinese records in the early 7th century bce. after the unification of the three kingdoms of korea into silla and balhae in the late 7th century, korea was ruled by the goryeo dynasty (918–1392) and the joseon '

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 'illion of which half live in the seoul capital area the ninth most populous metropolitan area in the world. other major cities include busan daegu and incheon.\n\nthe korean peninsula was inhabited as early as the lower paleolithic period. its first kingdom was noted in chinese records in the early th century bce. after the unification of the three kingdoms of korea into silla and balhae in the late th century korea was ruled by the goryeo dynasty  and the joseon dynasty . the succeeding korean em'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# [' it constitutes the southern part of the korean peninsula and borders north korea along the korean demilitarized zone though it also claims the land border with china and russia',
#  'e the countrys western border is formed by the yellow sea while its eastern border is defined by the sea of japan']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['south',
#  'korea',
#  'claims',
#  'to',
#  'be',
#  'the',
#  'sole',
#  'legitimate',
#  'government',
#  'of',
#  'the',
#  'entire',
#  'peninsula',
#  'and',
#  'adjacent',
#  'islands']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + [""]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['russia']
# Out:
# defaultdict(int,
#             {'and': 2,
#              '': 2,
#              'japan': 1,
#              'with': 1,
#              'as': 1,
#              'through': 1,
#              'analyzed': 1,
#              'the': 1})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'south',
#  'koreac',
#  'officially',
#  'the',
#  'republic',
#  'of',
#  'korea',
#  'rokd',
#  'is']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#             <START>  south  koreac  officially  the  republic   of  korea  \
# <START>           0     66       0           0  109         0    8      3
# south            66      0       1           0   24         0   21    154
# koreac            0      1       0           1    0         0    0      0
# officially        0      0       1           0    1         0    0      0
# the             109     24       0           1    0        13  143      9
# ...             ...    ...     ...         ...  ...       ...  ...    ...
# gaming            0      0       0           0    1         0    0      0
# esports           0      0       0           0    0         0    0      0
# young             0      0       0           0    0         0    0      0
# legends           0      0       0           0    0         0    1      0
# starcraft         0      0       0           0    0         0    0      0
#
#             rokd  is  ...  gyeonggi  closest  tracks  competitive  video  \
# <START>        0   0  ...         0        0       0            1      0
# south          0   1  ...         0        0       0            0      0
# koreac         0   0  ...         0        0       0            0      0
# officially     0   0  ...         0        0       0            0      0
# the            0  13  ...         0        0       0            0      0
# ...          ...  ..  ...       ...      ...     ...          ...    ...
# gaming         0   0  ...         0        0       0            0      1
# esports        0   0  ...         0        0       0            0      0
# young          0   0  ...         0        0       0            0      0
# legends        0   0  ...         0        0       0            0      0
# starcraft      0   0  ...         0        0       0            0      0
#
#             gaming  esports  young  legends  starcraft
# <START>          0        0      0        0          0
# south            0        0      0        0          0
# koreac           0        0      0        0          0
# officially       0        0      0        0          0
# the              1        0      0        0          0
# ...            ...      ...    ...      ...        ...
# gaming           0        0      0        0          0
# esports          0        0      0        0          0
# young            0        0      0        0          0
# legends          0        0      0        0          0
# starcraft        0        0      0        0          0
#
# [3103 rows x 3103 columns]
